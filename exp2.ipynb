# %%
#km to m
km=float(input("Enter distance im kilometers: "))
miles = km *0.62137
print("Distance in miles =", round(miles, 2))
# Out:
# Enter distance im kilometers: 3
# Distance in miles = 1.86

# %%
#convert celcius to fahrenhiet
c=float(input("enter the temperature in celcius: "))
f=c*9/5+32
print("temperature in fahrenhiet = ",f)
# Out:
# enter the temperature in celcius: 5
# temperature in fahrenhiet =  41.0
